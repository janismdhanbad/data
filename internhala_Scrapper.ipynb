# %%
from urllib2 import urlopen

from bs4 import BeautifulSoup
import pandas as pd
import re

import numpy as np

# %% [markdown]
# ### Add the category type of internship which you want to scrape

# %%
html1 = urlopen("https://internshala.com/internships/data%20science-internship/page-1")
html_soup1 = BeautifulSoup(html1, 'html.parser')
#beers_list = get_all_beers(html_soup)

html2 = urlopen("https://internshala.com/internships/data%20science-internship/page-2")
html_soup2 = BeautifulSoup(html2, 'html.parser')
#beers_list = get_all_beers(html_soup)

# %%
internships_and_jobs1 = pd.DataFrame(np.arange(1000),columns=["Nature_of_job"])
internships_and_jobs2 = pd.DataFrame(np.arange(1000),columns=["Nature_of_job"])

# %%
internships_and_jobs1["name_of_company"] = np.nan
internships_and_jobs1["start_date"] = np.nan
internships_and_jobs1["duration"] = np.nan
internships_and_jobs1["stipened"] = np.nan
internships_and_jobs1["posted_on"] = np.nan
internships_and_jobs1["apply_by"] = np.nan
internships_and_jobs1["brief_description"] = np.nan
internships_and_jobs1["Nature_of_job"] = np.nan
internships_and_jobs1["city"] = np.nan

internships_and_jobs2["name_of_company"] = np.nan
internships_and_jobs2["start_date"] = np.nan
internships_and_jobs2["duration"] = np.nan
internships_and_jobs2["stipened"] = np.nan
internships_and_jobs2["posted_on"] = np.nan
internships_and_jobs2["apply_by"] = np.nan
internships_and_jobs2["brief_description"] = np.nan
internships_and_jobs2["Nature_of_job"] = np.nan
internships_and_jobs2["city"] = np.nan

# %% [markdown]
# #### Name of comapany

# %%
name_of_company = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[0].findAll('h4')[1].findAll('a')[0].get('title'))

# %%
name_of_company
# Out:
# 'Administrative Staff College Of India'

# %% [markdown]
# #### Nature of job

# %%
nature_of_job = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[0].findAll('div',attrs={"class":"individual_internship_header"})[0].findAll('div',attrs={"class":"table-cell"})[0].findAll('h4')[0].get('title'))

# %%
nature_of_job
# Out:
# 'Research (Finance/Management)'

# %% [markdown]
# #### descripton of the job

# %%
brief_description = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[0].findAll('div',attrs={"class":"individual_internship_header"})[0].findAll('div',attrs={"class":"table-cell"})[1].findAll('div',attrs={"class":"internship_logo"})[0].findAll('img')[0].get('alt'))

# %%
brief_description
# Out:
# 'Research (Finance/Management) Internship at Administrative Staff College Of India in Hyderabad'

# %% [markdown]
# #### city of the internship

# %%
city = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[0].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('a')[0].contents[0])

# %%
city
# Out:
# 'Hyderabad'

# %% [markdown]
# #### when to start

# %%
when_to_start = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[0].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[0].findAll('div',attrs={"id":"start-date-first"})[0].contents[0])

# %%
when_to_start = re.sub('\r\n','',when_to_start)

when_to_start = re.sub(' ','',when_to_start)

# %%
when_to_start
# Out:
# 'Immediately'

# %% [markdown]
# #### duration

# %%
duration = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[0].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[1].contents[0])

# %%
duration = re.sub('\r\n','',duration)
duration =re.sub(' ','',duration)

# %%
duration
# Out:
# '3Months'

# %% [markdown]
# #### stipend

# %%
stipend = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[5].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[2].contents[2])

# %%
stipend = re.sub(' ','',stipend)

# %%
stipend
# Out:
# '8000-10000/Month'

# %% [markdown]
# #### posted on

# %%
posted_on = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[5].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[3].contents[0])

# %%
posted_on = re.sub(' ','',posted_on)
posted_on = re.sub('\r\n','',posted_on)

# %%
posted_on
# Out:
# "28Dec'16"

# %% [markdown]
# #### apply by

# %%
apply_by = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[5].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[4].contents[0])

# %%
apply_by = re.sub('\r\n','',apply_by)
apply_by = re.sub(' ','',apply_by)

# %%
apply_by
# Out:
# "31Jan'17"

# %%
html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[5].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')
# Out:
# [<td>\n<div id="start-date-first">\r\n                                Immediately                            </div>\n</td>,
#  <td>\r\n                            2 Months                        </td>,
#  <td>\n<i class="fa fa-inr"></i>8000-10000 /Month                                                    </td>,
#  <td>\r\n                            28 Dec'16                        </td>,
#  <td>\r\n                            31 Jan'17                        </td>]

# %%
total = len(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"}))

# %%
np.arange(1)
# Out:
# array([0])

# %%
total
# Out:
# 40

# %%
for i in np.arange(total):
    list2 = []
    try :
        name_of_company = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_header"})[0].findAll('div',attrs={"class":"table-cell"})[0].findAll('h4')[1].findAll('a')[0].contents[0])
        internships_and_jobs2.name_of_company.iloc[i] = name_of_company
        
    except IndexError :
        internships_and_jobs2.name_of_company.iloc[i] = "no_value"
    try:    
        nature_of_job = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_header"})[0].findAll('div',attrs={"class":"table-cell"})[0].findAll('h4')[0].get('title'))
        internships_and_jobs2.Nature_of_job.iloc[i] = nature_of_job
    except IndexError:
        internships_and_jobs2.Nature_of_job.iloc[i] = "no_value"
    try:
        brief_description = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_header"})[0].findAll('div',attrs={"class":"table-cell"})[1].findAll('div',attrs={"class":"internship_logo"})[0].findAll('img')[0].get('alt'))
        internships_and_jobs2.brief_description.iloc[i] = brief_description
    except IndexError:
        internships_and_jobs2.brief_description.iloc[i] = "no_value"
    try:
        city = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('a')[0].contents[0])
        internships_and_jobs2.city.iloc[i] = city
    except IndexError:
        internships_and_jobs2.city.iloc[i] ="no_value"
    try:
        when_to_start = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[0].findAll('div',attrs={"id":"start-date-first"})[0].contents[0])
        when_to_start = re.sub('\r\n','',when_to_start)
        when_to_start = re.sub(' ','',when_to_start)
        internships_and_jobs2.start_date.iloc[i] = when_to_start
    except IndexError:
        internships_and_jobs2.start_date.iloc[i] = "no_value"
    try:
        stipend = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[2].contents[2])
        stipend = re.sub(' ','',stipend)        
        internships_and_jobs2.stipened.iloc[i] = stipend
    except IndexError:
        internships_and_jobs2.stipened.iloc[i] = "no_value"
    try:
        apply_by = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[4].contents[0])
        apply_by = re.sub('\r\n','',apply_by)
        apply_by = re.sub(' ','',apply_by)
        internships_and_jobs2.apply_by.iloc[i] = apply_by
    except IndexError:
        internships_and_jobs2.apply_by.iloc[i] = "no_value"
    try:
        posted_on = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[3].contents[0])
        posted_on = re.sub(' ','',posted_on)
        posted_on = re.sub('\r\n','',posted_on)
        internships_and_jobs2.posted_on.iloc[i] = posted_on
    except IndexError:
        internships_and_jobs2.posted_on.iloc[i] = "no_value"
    try:    
        duration = str(html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[1].contents[0])
        duration = re.sub('\r\n','',duration)
        duration =re.sub(' ','',duration)        
        internships_and_jobs2.duration.iloc[i] = duration
    except IndexError:    
        internships_and_jobs2.duration.iloc[i] = "no_value"

# %%
internships_and_jobs2.iloc[0:40,:]
# Out:
#                                         Nature_of_job  \
# 0                       Research (Finance/Management)
# 1                    Business Analyst - Customer Care
# 2   Android Application & Machine Learning Based R...
# 3                  Data Analytics & Big Data Research
# 4                                        Data Science
# 5                                Technology Analytics
# 6                        Artificial Intelligence (AI)
# 7                             Product Data Management
# 8                         Internet Marketing Research
# 9                          IIT JEE Questions Analysis
# 10                                 Business Analytics
# 11                                           Big Data
# 12                       Artificial Intelligence (AI)
# 13                     Artificial Intelligence Intern
# 14                                       Data Science
# 15      Data Science - Analytical Product Development
# ...

# %%
html_soup.findAll('div',attrs={"class":"container-fluid individual_internship"})[i]

# %%
total2 = len(html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"}))

# %%
for i in np.arange(total2):
    
    try :
        name_of_company = str(html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_header"})[0].findAll('div',attrs={"class":"table-cell"})[0].findAll('h4')[1].findAll('a')[0].contents[0])
        internships_and_jobs1.name_of_company.iloc[total+i] = name_of_company
        
    except IndexError :
        internships_and_jobs1.name_of_company.iloc[total+i] = "no_value"
    try:    
        nature_of_job = str(html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_header"})[0].findAll('div',attrs={"class":"table-cell"})[0].findAll('h4')[0].get('title'))
        internships_and_jobs1.Nature_of_job.iloc[total+i] = nature_of_job
    except IndexError:
        internships_and_jobs1.Nature_of_job.iloc[total+i] = "no_value"
    try:
        brief_description = str(html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_header"})[0].findAll('div',attrs={"class":"table-cell"})[1].findAll('div',attrs={"class":"internship_logo"})[0].findAll('img')[0].get('alt'))
        internships_and_jobs1.brief_description.iloc[total+i] = brief_description
    except IndexError:
        internships_and_jobs1.brief_description.iloc[total+i] = "no_value"
    try:
        city = str(html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('a')[0].contents[0])
        internships_and_jobs1.city.iloc[total+i] = city
    except IndexError:
        internships_and_jobs1.city.iloc[total+i] ="no_value"
    try:
        when_to_start = str(html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[0].findAll('div',attrs={"id":"start-date-first"})[0].contents[0])
        when_to_start = re.sub('\r\n','',when_to_start)
        when_to_start = re.sub(' ','',when_to_start)
        internships_and_jobs1.start_date.iloc[total+i] = when_to_start
    except IndexError:
        internships_and_jobs1.start_date.iloc[total+i] = "no_value"
    try:
        stipend = str(html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[2].contents[2])
        stipend = re.sub(' ','',stipend)        
        internships_and_jobs1.stipened.iloc[total+i] = stipend
    except IndexError:
        internships_and_jobs1.stipened.iloc[total+i] = "no_value"
    try:
        apply_by = str(html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[4].contents[0])
        apply_by = re.sub('\r\n','',apply_by)
        apply_by = re.sub(' ','',apply_by)
        internships_and_jobs1.apply_by.iloc[total+i] = apply_by
    except IndexError:
        internships_and_jobs1.apply_by.iloc[total+i] = "no_value"
    try:
        posted_on = str(html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[3].contents[0])
        posted_on = re.sub(' ','',posted_on)
        posted_on = re.sub('\r\n','',posted_on)
        internships_and_jobs1.posted_on.iloc[total+i] = posted_on
    except IndexError:
        internships_and_jobs1.posted_on.iloc[total+i] = "no_value"
    try:    
        duration = str(html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_details"})[0].findAll('td')[1].contents[0])
        duration = re.sub('\r\n','',duration)
        duration =re.sub(' ','',duration)        
        internships_and_jobs1.duration.iloc[total+i] = duration
    except IndexError:    
        internships_and_jobs1.duration.iloc[total+i] = "no_value"

# %%
internships_and_jobs1.iloc[40:81,:]
# Out:
#                             Nature_of_job  \
# 40                       Machine Learning
# 41                             Operations
# 42                       Machine Learning
# 43                 Social Media Marketing
# 44           Artificial Intelligence (AI)
# 45                 Social Media Marketing
# 46                        Content Writing
# 47  Model Verification/Analytical Testing
# 48        Deep Learning & Computer Vision
# 49     Business Analyst - Urgent Position
# 50                      Research Analysis
# 51                 Social Media Marketing
# 52                     Product Management
# 53                              Marketing
# 54                     Business Analytics
# 55      Disease State Research & Analysis
# 56                  Clinical Data Analyst
# 57                     Business Analytics
# 58     Government Startup Policy Research
# 59                      Software Analysis
# 60     Software And Algorithm Development
# ...

# %%
html_soup2.findAll('div',attrs={"class":"container-fluid individual_internship"})[i].findAll('div',attrs={"class":"individual_internship_header"})[0].findAll('div',attrs={"class":"table-cell"})[0].findAll('h4')
# Out:
# [<h4 title="Research Analysis">\r\n                Research Analysis\r\n            </h4>,
#  <h4><a href="/internships/internship-at-Sattva%20Investment%20Advisors%20Pvt.%20Ltd" title="Sattva Investment Advisors Pvt. Ltd">Sattva Investment Advisors Pvt. Ltd</a></h4>]
